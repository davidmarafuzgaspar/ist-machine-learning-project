# %%
# Optimal Nonlinear Regression Solution

This notebook implements the best nonlinear regression solution based on comprehensive analysis of multiple approaches.

## Performance Summary from Analysis:
- **Kernel Ridge Regression (RBF)**: R² = 0.9926 (Best individual model)
- **SVR (RBF)**: R² = 0.9899
- **RBF + Ridge**: R² = 0.9698
- **Spline Regression**: R² = 0.9480
- **Polynomial Regression**: R² = 0.9167 (degree 4)

## Optimal Solution: Advanced Ensemble Approach

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR
from sklearn.ensemble import VotingRegressor, RandomForestRegressor
from sklearn.model_selection import KFold, train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.linear_model import Ridge
from sklearn.preprocessing import SplineTransformer
from scipy.stats import zscore
from sklearn.ensemble import IsolationForest
from itertools import product
import warnings
warnings.filterwarnings('ignore')

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
